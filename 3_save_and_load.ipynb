# %%
import pandas as pd
import numpy as np

# %%
#conectando el colab con drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/Cursos_Y_Proyectos/Manipulacion_de_datos_con_pandas'
# !ls
# Out:
# /content/drive/My Drive/Cursos_Y_Proyectos/Manipulacion_de_datos_con_pandas
# 1_pandas_series_e_indexacion_de_datos.ipynb  3_save_and_load.ipynb
# 2_pruebas_dataframes.ipynb		     db

# %%
#Creo carpeta
# !mkdir /content/drive/My\ Drive/Cursos_Y_Proyectos/Manipulacion_de_datos_con_pandas/db
# Out:
# mkdir: cannot create directory ‘/content/drive/My Drive/Cursos_Y_Proyectos/Manipulacion_de_datos_con_pandas/db’: File exists

# %%
dict_data = {
    'edad': [10,9,13,14,12,11,12],
    'cm': [115,110,130,155,125,120,125],
    'pais':['co','mx','co','mx','mx','ch','ch'],
    'genero':['M','F','F','M','M','M','F'],
    'Q1':[5,10,8,np.nan,7,8,3],
    'Q2':[7,9,9,8,8,8,9]}

dict_data
# Out:
# {'Q1': [5, 10, 8, nan, 7, 8, 3],
#  'Q2': [7, 9, 9, 8, 8, 8, 9],
#  'cm': [115, 110, 130, 155, 125, 120, 125],
#  'edad': [10, 9, 13, 14, 12, 11, 12],
#  'genero': ['M', 'F', 'F', 'M', 'M', 'M', 'F'],
#  'pais': ['co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch']}

# %%
df = pd.DataFrame(dict_data)
df
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
dir_pandas = '/content/drive/My Drive/Cursos_Y_Proyectos/Manipulacion_de_datos_con_pandas/db/{}'.format('test.csv')
dir_pandas
# Out:
# '/content/drive/My Drive/Cursos_Y_Proyectos/Manipulacion_de_datos_con_pandas/db/test.csv'

# %%
#aca guarda el index, es decir los indices
df.to_csv(dir_pandas)

# %%
dir_pandas = '/content/drive/My Drive/Cursos_Y_Proyectos/Manipulacion_de_datos_con_pandas/db/{}'.format('test2.csv')
dir_pandas
# Out:
# '/content/drive/My Drive/Cursos_Y_Proyectos/Manipulacion_de_datos_con_pandas/db/test2.csv'

# %%
#aca NO guarda el index
df.to_csv(dir_pandas, index=False)

# %%
# !ls /content/drive/My\ Drive/Cursos_Y_Proyectos/Manipulacion_de_datos_con_pandas/db/
# Out:
# test2.csv  test3.csv  test.csv

# %%
df_read = pd.read_csv('/content/drive/My Drive/Cursos_Y_Proyectos/Manipulacion_de_datos_con_pandas/db/test2.csv')

# %%
df_read
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
dir_pandas = '/content/drive/My Drive/Cursos_Y_Proyectos/Manipulacion_de_datos_con_pandas/db/{}'.format('test3.csv')
dir_pandas
# Out:
# '/content/drive/My Drive/Cursos_Y_Proyectos/Manipulacion_de_datos_con_pandas/db/test3.csv'

# %%
#aca NO guarda el index, y cambia separador
df.to_csv(dir_pandas, sep='|', index=False)

# %%
df_read2 = pd.read_csv('/content/drive/My Drive/Cursos_Y_Proyectos/Manipulacion_de_datos_con_pandas/db/test3.csv', sep='|')
df_read2
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
dir_pandas = '/content/drive/My Drive/Cursos_Y_Proyectos/Manipulacion_de_datos_con_pandas/db/{}'
dir_pandas
# Out:
# '/content/drive/My Drive/Cursos_Y_Proyectos/Manipulacion_de_datos_con_pandas/db/{}'

# %%
df.to_excel(dir_pandas.format('test_excel1.xlsx'), index=False, sheet_name='prueba_excel')

# %%
pd_read_excel = pd.read_excel(dir_pandas.format('test_excel1.xlsx'))
pd_read_excel
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
df.to_json(dir_pandas.format('test_json.json'))

# %%
pd_read_json = pd.read_json(dir_pandas.format('test_json.json'))
pd_read_json
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
df.to_pickle(dir_pandas.format('test.pkl'))

# %%
read_picke = pd.read_pickle(dir_pandas.format('test.pkl'))
read_picke
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
df.to_parquet(dir_pandas.format('test.parquet'))
df.to_hdf(dir_pandas.format('test.hdf'), key='data', format='table')

# %%
pd_read_parquet = pd.read_parquet(dir_pandas.format('test.parquet'))
pd_read_parquet
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
pd_read_hdf = pd.read_hdf(dir_pandas.format('test.hdf'))
pd_read_hdf
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9
