# %%
import pandas as pd

# %%
pd.Series([10,9,8,7,6])
# Out:
# 0    10
# 1     9
# 2     8
# 3     7
# 4     6
# dtype: int64

# %%
sr = pd.Series([10,9,8,7,6])

# %%
sr.values
# Out:
# array([10,  9,  8,  7,  6])

# %%
sr.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
sr.shape
# Out:
# (5,)

# %%
sr[[0,4,2]] #escogiendo los elementos por posicion , en este caso 0,4,2
# Out:
# 0    10
# 4     6
# 2     8
# dtype: int64

# %%
sr = pd.Series([10,9,8,7,6,5], index=['a','b','c','d','e','f'])

# %%
sr['d']
# Out:
# 7

# %%
sr['b':'e']
# Out:
# b    9
# c    8
# d    7
# e    6
# dtype: int64

# %%
dict_data = {'CO':100, 'MX':200, 'AR':300}
dict_data
# Out:
# {'AR': 300, 'CO': 100, 'MX': 200}

# %%
dict_data.keys()
# Out:
# dict_keys(['CO', 'MX', 'AR'])

# %%
dict_data['MX']
# Out:
# 200

# %%
#Convirtiendo diccionario en serie
pd.Series(dict_data)
# Out:
# CO    100
# MX    200
# AR    300
# dtype: int64

# %%
#Lo mismo pero agrego Peru 'PE'
pd.Series(dict_data, index=['CO','PE','MX','AR'])
# Out:
# CO    100.0
# PE      NaN
# MX    200.0
# AR    300.0
# dtype: float64

# %%
import numpy as np

# %%
#creando objeto nulo
np.nan
# Out:
# nan

# %%
#siempre va a dar nulo asi hagamos una operacion
np.nan + 10
# Out:
# nan

# %%
sr.isnull().any() #Hay algun nulo
# Out:
# False

# %%
sr.isnull() #Hay nulos?
# Out:
# a    False
# b    False
# c    False
# d    False
# e    False
# f    False
# dtype: bool

# %%
sr[sr.notnull()] #trae los que no son nulos
# Out:
# a    10
# b     9
# c     8
# d     7
# e     6
# f     5
# dtype: int64
